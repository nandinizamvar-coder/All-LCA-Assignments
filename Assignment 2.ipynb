# %%
#Assignment 2: Program to find the largest of three numbers

# %%
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))
num3 = float(input("Enter the third nummber: "))

if num1 >= num2 and num1 >=num3:
    largest = num1
elif num2 >= num1 and num2 >=num3:
    largest = num2
else:
    largest = num3

print("The largest number is:", largest)
# Out:
# Enter the first number:  74
# Enter the second number:  83
# Enter the third nummber:  64
# The largest number is: 83.0
